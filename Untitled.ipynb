# %%
from pymongo import MongoClient
client = MongoClient()
db = client['tweet-link-data']
for doc in db[db.collection_names(include_system_collections=False)[0]].find():
    print (doc)
# Out:
# {'id': 777402116566646800, 'images': ['http://www.activistpost.com/wp-content/uploads/2012/01/Nikola-Tesla-120x67.jpg', 'http://www.activistpost.com/wp-content/uploads/2016/09/police-DAPL-UR-120x67.jpg', 'http://pbs.twimg.com/profile_images/709886591976628224/6kjfjyZD_normal.jpg', 'http://www.activistpost.com/wp-content/uploads/2016/02/chemtrails00000-120x67.jpg', 'https://lh3.googleusercontent.com/-Oq5Im_ize04/VmRks0yjT4I/AAAAAAAACGk/lZjOmUnvnGk/s250-Ic42/LFL_SPY_101SpySecrets_250x250.jpg', 'http://www.activistpost.com/wp-content/uploads/2016/10/internet-120x67.jpg', 'http://www.activistpost.com/wp-content/uploads/2016/09/ransom.jpg', 'http://www.activistpost.com/wp-content/uploads/2016/09/dead-scientists-120x67.jpg', 'http://www.activistpost.com/wp-content/uploads/2016/07/money-where-does-it-go-777x437-120x67.jpg', 'http://www.activistpost.com/wp-content/uploads/2016/09/vaccine-glyphosate-120x67.jpg', 'http://www.activistpost.com/wp-content/uploads/2016/09/2nd-amendment-120x67.jpg'
# ...
